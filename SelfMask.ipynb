# %%
# %cd /content
# %rm -rf selfmask
# !git clone https://github.com/HaiDang2001VN/selfmask selfmask
# %cd /content/selfmask
# %ls -sla
# Out:
# /content
# Cloning into 'selfmask'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 163 (delta 60), reused 133 (delta 35), pack-reused 0
# Receiving objects: 100% (163/163), 12.85 MiB | 24.93 MiB/s, done.
# Resolving deltas: 100% (60/60), done.
# /content/selfmask
# total 140
#  4 drwxr-xr-x 12 root root  4096 Feb 19 09:56 ./
#  4 drwxr-xr-x  1 root root  4096 Feb 19 09:56 ../
#  4 -rw-r--r--  1 root root  3988 Feb 19 09:56 base_structure.py
#  4 drwxr-xr-x  2 root root  4096 Feb 19 09:56 clusterings/
#  4 drwxr-xr-x  2 root root  4096 Feb 19 09:56 configs/
# 16 -rw-r--r--  1 root root 15208 Feb 19 09:56 criterion.py
#  4 drwxr-xr-x  3 root root  4096 Feb 19 09:56 datasets/
# 16 -rw-r--r--  1 root root 14872 Feb 19 09:56 evaluator.py
#  4 drwxr-xr-x  8 root root  4096 Feb 19 09:56 .git/
#  4 -rw-r--r--  1 root root    12 Feb 19 09:56 .gitignore
# ...

# %%
# %cd /content/selfmask
# !git pull
# Out:
# /content/selfmask
# Already up to date.

# %%
# %cd /content/selfmask
# !pip install -r requirements.txt
# Out:
# /content/selfmask
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 MB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 109.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 KB 13.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 KB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.9/216.9 KB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 86.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 60.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd /content
# %mkdir /content/dataset
# %ls -sla /content/dataset
# Out:
# /content
# total 8
# 4 drwxr-xr-x 2 root root 4096 Feb 19 09:56 ./
# 4 drwxr-xr-x 1 root root 4096 Feb 19 09:56 ../

# %%
# %cd /content
# !sh selfmask/scripts/download_tr.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: DUTS-TR/DUTS-TR-Mask/n07718747_3382.png
#   inflating: DUTS-TR/DUTS-TR-Mask/n04270147_12691.png
#  extracting: DUTS-TR/DUTS-TR-Mask/n03211117_3402.png
#  extracting: DUTS-TR/DUTS-TR-Mask/ILSVRC2012_test_00000680.png
#   inflating: DUTS-TR/DUTS-TR-Mask/ILSVRC2012_val_00036949.png
#   inflating: DUTS-TR/DUTS-TR-Mask/ILSVRC2014_train_00033735.png
#   inflating: DUTS-TR/DUTS-TR-Mask/n01644900_4125.png
#   inflating: DUTS-TR/DUTS-TR-Mask/n04540053_2438.png
#   inflating: DUTS-TR/DUTS-TR-Mask/n03770439_7684.png
#   inflating: DUTS-TR/DUTS-TR-Mask/n07873807_5318.png
#   inflating: DUTS-TR/DUTS-TR-Mask/ILSVRC2014_train_00010870.png
#   inflating: DUTS-TR/DUTS-TR-Mask/n03764736_1884.png
#   inflating: DUTS-TR/DUTS-TR-Mask/n07742313_494.png
#  extracting: DUTS-TR/DUTS-TR-Mask/n03770439_218.png
#   inflating: DUTS-TR/DUTS-TR-Mask/ILSVRC2013_test_00009085.png
#   inflating: DUTS-TR/DUTS-TR-Mask/ILSVRC2012_test_00000909.png
# ...

# %%
# %cd /content
# !sh selfmask/scripts/download_te.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00082351.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00082798.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00006593.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00011235.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00082541.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00070363.png
#   inflating: DUTS-TE/DUTS-TE-Mask/sun_bceuokyqoqhfsper.png
#   inflating: DUTS-TE/DUTS-TE-Mask/sun_abydfmdyqyieeram.png
#  extracting: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00070467.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00081849.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2013_test_00002195.png
#   inflating: DUTS-TE/DUTS-TE-Mask/sun_birvjjkruobbrzse.png
#   inflating: DUTS-TE/DUTS-TE-Mask/sun_aeraygrwrxmiozxx.png
#   inflating: DUTS-TE/DUTS-TE-Mask/ILSVRC2012_test_00091690.png
# ...

# %%
# %cd /content
# !sh selfmask/scripts/download_ecssd.sh
# Out:
# /content
# --2023-02-19 09:59:43--  https://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/images.zip
# Resolving www.cse.cuhk.edu.hk (www.cse.cuhk.edu.hk)... 137.189.91.192
# Connecting to www.cse.cuhk.edu.hk (www.cse.cuhk.edu.hk)|137.189.91.192|:443... connected.
# WARNING: cannot verify www.cse.cuhk.edu.hk's certificate, issued by ‘CN=Sectigo RSA Domain Validation Secure Server CA,O=Sectigo Limited,L=Salford,ST=Greater Manchester,C=GB’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 67766979 (65M) [application/zip]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]  64.63M  16.1MB/s    in 7.1s
#
# 2023-02-19 09:59:51 (9.13 MB/s) - ‘images.zip’ saved [67766979/67766979]
#
# --2023-02-19 09:59:51--  https://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/ground_truth_mask.zip
# Resolving www.cse.cuhk.edu.hk (www.cse.cuhk.edu.hk)... 137.189.91.192
# ...

# %%
# %cd /content
# !sh selfmask/scripts/download_omron.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/DUT-OMRON-image/._sun_alwzusjhljjlzuwe.jpg
#   inflating: DUT-OMRON-image/sun_awtnxjjmbaybyxfn.jpg
#   inflating: __MACOSX/DUT-OMRON-image/._sun_awtnxjjmbaybyxfn.jpg
#   inflating: DUT-OMRON-image/sun_alkurxblxnqfsumv.jpg
#   inflating: __MACOSX/DUT-OMRON-image/._sun_alkurxblxnqfsumv.jpg
#   inflating: DUT-OMRON-image/sun_ajbsvlfgxtabdeia.jpg
#   inflating: __MACOSX/DUT-OMRON-image/._sun_ajbsvlfgxtabdeia.jpg
#   inflating: DUT-OMRON-image/sun_aajqfxfmwkpwuibp.jpg
#   inflating: __MACOSX/DUT-OMRON-image/._sun_aajqfxfmwkpwuibp.jpg
#   inflating: DUT-OMRON-image/sun_agzdcrvkwlrkboci.jpg
#   inflating: __MACOSX/DUT-OMRON-image/._sun_agzdcrvkwlrkboci.jpg
#   inflating: DUT-OMRON-image/sun_akltcbkzrqttydda.jpg
#   inflating: __MACOSX/DUT-OMRON-image/._sun_akltcbkzrqttydda.jpg
#   inflating: DUT-OMRON-image/sun_ayjaxekjnafrrnas.jpg
#   inflating: __MACOSX/DUT-OMRON-image/._sun_ayjaxekjnafrrnas.jpg
# ...

# %%
# %cd /content/selfmask/scripts
# !sh train-selfmask-nq20.sh
# Out:
# /content/selfmask/scripts
#
# /content/selfmask/ckpt/nq20_ndl6_bc_sr10100_duts_pm_seed0 is created.
#
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: haidang2001vn (use `wandb login --relogin` to force relogin)
# 2023-02-19 10:02:06.760615: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
